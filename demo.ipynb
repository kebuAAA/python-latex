# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.DataFrame({'A':range(1,5),'B':list('abcd')})
data.to_latex('./tex代码/table.tex',caption='A simple Table',label='tab:table1',index=False,position='h')
plt.plot([0,1],[0,1])
plt.savefig('./asset/figure.eps',dpi=300)
